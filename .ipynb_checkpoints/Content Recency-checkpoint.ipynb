# %%
from htmldate import find_date
import pandas as pd
import time
from ipynb.fs.full.functions import *

# %% [markdown]
# ### Notes
#
# The package <b>htmldate</b> has a `precision` of `0.899` and an `accuracy` of `0.831`. This means that only about `90%` of the input URL's will give output and that the output is only about `83%` accurate. This is however the most precise and accurate package there is at this moment.

# %%
websites = GetWebsites()

# returns dataframe with the original publication date and last modified date, which are often the same date
def GetContentRecency():
    rows_list = []
    counter = 0
    usable_counter = 0
    
    start = time.time() # used for debugging
    for key,value in websites.iteritems():
        counter = counter+1
        try:
            original = find_date(value,original_date=True)
            last_modified = find_date(value)
            if last_modified is None:
                rows_list.append({"original_publication":"NaN","last_modified":"NaN"})
            else:
                rows_list.append({"original_publication":original,"last_modified":last_modified})
                usable_counter = usable_counter+1 
            print("Nummer: ",usable_counter) # used for debugging
            print("URL: ",value) # used for debugging
            print("Original publication date: ",original) # used for debugging
            print("Last modified: ",last_modified) # used for debugging
        except:
            print("URL: ",value) # used for debugging
            print("ERROR") # used for debugging
            rows_list.append({"original_publication":"NaN","last_modified":"NaN"})
            continue
    end = time.time() # used for debugging
    
    df = pd.DataFrame(rows_list)
    print("Amount of usable returns: ", usable_counter) # used for debugging
    print("Run time: ", end - start, " seconds") # used for debugging
    return df

# %%
GetContentRecency()
# Out:
# Nummer:  1
# URL:  https://www.bouwmaat.nl/bouwmaterialen
# Original publication date:  2021-04-28
# Last modified:  2021-04-28
# Nummer:  2
# URL:  https://www.hornbach.nl/shop/Bouwmateriaal/S4471/artikeloverzicht.html
# Original publication date:  2020-01-01
# Last modified:  2020-01-01
# Nummer:  3
# URL:  https://www.bouwbestel.nl/bouwmaterialen.html
# Original publication date:  2007-01-01
# Last modified:  2021-01-01
# Nummer:  4
# URL:  https://www.online-bouwmaterialen.nl/
# Original publication date:  2011-01-01
# Last modified:  2011-01-01
# Nummer:  5
# URL:  https://www.bmn.nl/
# Original publication date:  2021-01-01
# Last modified:  2021-01-01
# Nummer:  6
# URL:  https://www.bouwonline.com/
# Original publication date:  2021-01-01
# Last modified:  2021-01-01
# Nummer:  6
# URL:  https://www.bol.com/nl/m/bouwmaterialen/
# Original publication date:  None
# Last modified:  None
# Nummer:  7
# URL:  https://www.pontmeyer.nl/
# Original publication date:  2021-01-01
# Last modified:  2021-01-01
# Nummer:  8
# URL:  https://www.bouwmaterialenkopen.com/
# Original publication date:  2021-04-22
# Last modified:  2021-04-22
# Nummer:  9
# URL:  https://www.debouwmarktshop.nl/
# Original publication date:  2021-01-01
# Last modified:  2021-01-01
# Nummer:  10
# URL:  https://www.huisman.nl/bouwmaterialen/
# Original publication date:  2000-01-01
# Last modified:  2000-01-01
# Nummer:  11
# URL:  https://www.sleiderink.nl/bouwmaterialen
# Original publication date:  2017-01-01
# Last modified:  2021-01-01
# Nummer:  12
# URL:  https://www.houtenbouwmaterialen.nl/bouwmaterialen
# Original publication date:  2021-01-01
# Last modified:  2021-01-01
# Nummer:  13
# URL:  https://www.raabkarcher.nl/bouwmaterialen
# Original publication date:  2015-01-01
# Last modified:  2015-01-01
# Nummer:  14
# URL:  https://www.karwei.nl/assortiment/k/bouwmaterialen
# Original publication date:  2021-01-01
# Last modified:  2021-01-01
# Nummer:  15
# URL:  https://www.stmiddelkoop.nl/bouwmaterialen/
# Original publication date:  2021-01-01
# Last modified:  2021-01-01
# Nummer: