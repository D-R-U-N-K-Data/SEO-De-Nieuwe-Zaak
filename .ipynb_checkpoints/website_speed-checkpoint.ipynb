# %%
from PythonPSI.api import PSI
import pandas as pd
import time
from ipynb.fs.full.functions import *

# %% [markdown]
# ### Notes
# This function is pretty slow, because it takes a while to get all the needed data with the API, especially when calling a lot of urls. With 50 urls, it takes about `15 minutes` to run.
#
# Not every url returns useable performance data, since the API has some restrictions. Some webpages require too many queries. With 50 urls, about `40 urls` return useable data.
#
# This function will need some refactoring at some point to enhance performance.

# %%
websites = GetWebsites() # test data

# returns a dict with the cls, fcp, fid and lcp from given websites dataframe with performance data
def GetSpecificPerformanceData(df):
    url = df.loc["CUMULATIVE_LAYOUT_SHIFT_SCORE","id"]
    cls = pd.DataFrame(df.loc["CUMULATIVE_LAYOUT_SHIFT_SCORE","metrics"]).percentile.iloc[0]
    fcp = pd.DataFrame(df.loc["FIRST_CONTENTFUL_PAINT_MS","metrics"]).percentile.iloc[0]
    fid = pd.DataFrame(df.loc["FIRST_INPUT_DELAY_MS","metrics"]).percentile.iloc[0]
    lcp = pd.DataFrame(df.loc["LARGEST_CONTENTFUL_PAINT_MS","metrics"]).percentile.iloc[0]
    results = {"URL":url,"FCP":fcp,"LCP":lcp,"FID":fid,"CLS":cls}
    return results

# returns dataframe with website performance data
def GetWebsiteSpeed(df):
    rows_list = []
    counter = 0
    all_counter = 0
    urls = df["Ur"]

    start = time.time() # used for debugging
    for key,value in websites.iteritems():
        # get data from Google Pagespeed Insights API
        data = PSI(value, category='performance', locale='en', stratergy='desktop', metrics='loadingExperience')
        data_keys = list(data.keys())
        print(data_keys) # used for debugging
        
        # don't add row to list when API call gives error or data is incomplete
        if data_keys != ['error']:
            if data_keys != ['initial_url']:
                print(value) # used for debugging
                print(data) # used for debugging
                rows_list.append(GetSpecificPerformanceData(pd.DataFrame(data)))
                counter = counter+1   
        else:
            print(value,": WEBSITE GIVES ERROR") # used for debugging
            rows_list.append({"URL":value,"FCP":"NaN","LCP":"NaN","FID":"NaN","CLS":"NaN"})
        all_counter = all_counter+1 # used for debugging
        print("COUNTER: ", all_counter) # used for debugging

    end = time.time() # used for debugging
    
    df = pd.DataFrame(rows_list)   
    df.to_csv(r'websitespeed.csv')
    print("Amount of usable returns: ", counter) # used for debugging
    print("Run time: ", (end - start)/60, " minutes") # used for debugging
    return df

# %%
d = {'Ur': ["https://www.bouwmaat.com/bouwmaterialen", "https://www.bouwbestel.nl/bouwmaterialen.html"], 'Iets': [3, 4]}
df = pd.DataFrame(data=d)
GetWebsiteSpeed(df)
# Out:
# ['id', 'metrics', 'overall_category', 'initial_url']
# https://www.bouwmaat.nl/bouwmaterialen
# {'id': 'https://www.bouwmaat.nl/bouwmaterialen', 'metrics': {'CUMULATIVE_LAYOUT_SHIFT_SCORE': {'percentile': 82, 'distributions': [{'min': 0, 'max': 10, 'proportion': 0.08292563600782796}, {'min': 10, 'max': 25, 'proportion': 0.018835616438356205}, {'min': 25, 'proportion': 0.8982387475538158}], 'category': 'SLOW'}, 'FIRST_CONTENTFUL_PAINT_MS': {'percentile': 1216, 'distributions': [{'min': 0, 'max': 1000, 'proportion': 0.6569238140872065}, {'min': 1000, 'max': 3000, 'proportion': 0.30378533780546235}, {'min': 3000, 'proportion': 0.039290848107331196}], 'category': 'AVERAGE'}, 'FIRST_INPUT_DELAY_MS': {'percentile': 5, 'distributions': [{'min': 0, 'max': 100, 'proportion': 0.946424568482404}, {'min': 100, 'max': 300, 'proportion': 0.0206231786594934}, {'min': 300, 'proportion': 0.03295225285810355}], 'category': 'FAST'}, 'LARGEST_CONTENTFUL_PAINT_MS': {'percentile': 2474, 'distributions': [{'min': 0, 'max': 2500, 'proportion': 0.751724931002757}, {'min': 2500, 'max': 4000, 'proportion': 0.16616835326586873}, {'min': 4000, 'proportion': 0.0821067157313699}], 'category': 'FAST'}}, 'overall_category': 'SLOW', 'initial_url': 'https://www
 'distributions': [{'min': 0, 'max': 2500, 'proportion': 0.9905309435238415}, {'min': 2500, 'max': 4000, 'proportion': 0.009469056476158259}, {'min': 4000, 'proportion': 0}], 'category': 'FAST'}}, 'overall_category': 'FAST', 'initial_url': 'https://www.sleiderink.nl/bouwmaterialen'}
# COUNTER:  12
# ['id', 'metrics', 'overall_category', 'initial_url', 'origin_fallback']
# https://www.houtenbouwmaterialen.nl/bouwmaterialen
# {'id': 'https://www.houtenbouwmaterialen.nl', 'metrics': {'CUMULATIVE_LAYOUT_SHIFT_SCORE': {'percentile': 11, 'distributions': [{'min': 0, 'max': 10, 'proportion': 0.7175368139223558}, {'min': 10, 'max': 25, 'proportion': 0.22356091030789815}, {'min': 25, 'proportion': 0.058902275769745674}], 'category': 'AVERAGE'}, 'FIRST_CONTENTFUL_PAINT_MS': {'percentile': 1179, 'distributions': [{'min': 0, 'max': 1000, 'proportion': 0.672028890347996}, {'min': 1000, 'max': 3000, 'proportion': 0.30334865397242217}, {'min': 3000, 'proportion': 0.024622455679579682}], 'category': 'AVERAGE'}, 'FIRST_INPUT_DELAY_MS': {'percentile': 3, 'distributions': [{'min': 0, 'max': 100, 'proportion': 0.9919234220759812}, {'min': 100, 'max': 300, 'proportion': 0.006880047861202523}, {'min': 300, 'proportion': 0.001196530062817831}], 'category': 'FAST'}, 'LARGEST_CONTENTFUL_PAINT_MS': {'percentile': 1759, 'distributions': [{'min': 0, 'max': 2500, 'proportion': 0.8749590298262849}, {'min': 2500, 'max': 4000, 'proportion': 0.08177646673221885}, {'min': 4000, 'proportion': 0.043264503441494614}], 'category': 'FAST'}}, 'overall_category': 'AVERAGE', 'initial_url': 'https://www.houtenbouwmaterialen.nl/bouwmaterialen', 'origin_fallback': True}
# COUNTER:  13
# ['id', 'metrics', 'overall_category', 'initial_url', 'origin_fallback']
# https://www.raabkarcher.nl/bouwmaterialen
# {'id': 'https://www.raabkarcher.nl', 'metrics': {'CUMULATIVE_LAYOUT_SHIFT_SCORE': {'percentile': 24, 'distributions': [{'min': 0, 'max': 10, 'proportion': 0.2865542924343397}, {'min': 10, 'max': 25, 'proportion': 0.46471971775774246}, {'min': 25, 'proportion': 0.24872598980791674}], 'category': 'AVERAGE'}, 'FIRST_CONTENTFUL_PAINT_MS': {'percentile': 2216, 'distributions': [{'min': 0, 'max': 1000, 'proportion': 0.4436335701939687}, {'min': 1000, 'max': 3000, 'proportion': 0.3965815248703658}, {'min': 3000, 'proportion': 0.15978490493566344}], 'category': 'AVERAGE'}, 'FIRST_INPUT_DELAY_MS': {'percentile': 3, 'distributions': [{'min': 0, 'max': 100, 'proportion': 0.9953085528690007}, {'min': 100, 'max': 300, 'proportion': 0.0036088054853843383}, {'min': 300, 'proportion': 0.0010826416456153015}], 'category': 'FAST'}, 'LARGEST_CONTENTFUL_PAINT_MS': {'percentile': 4592, 'distributions': [{'min': 0, 'max': 2500, 'proportion': 0.43759469696969466}, {'min': 2500, 'max': 4000, 'proportion': 0.25255681818181686}, {'min': 4000, 'proportion': 0.3098484848484851}], 'category': 'SLOW'}}, 'overall_category': 'SLOW', 'initial_url': 'https://www.raabkarcher.nl/bouwmaterialen', 'origin_fallback': True}
# COUNTER:  14
# ['id', 'metrics', 'overall_category', 'initial_url']
# https://www.karwei.nl/assortiment/k/bouwmaterialen
# {'id': 'https://www.karwei.nl/assortiment/k/bouwmaterialen', 'metrics': {'CUMULATIVE_LAYOUT_SHIFT_SCORE': {'percentile': 4, 'distributions': [{'min': 0, 'max': 10, 'proportion': 0.9803508771929832}, {'min': 10, 'max': 25, 'proportion': 0.00982456140350878}, {'min': 25, 'proportion': 0.009824561403508795}], 'category': 'FAST'}, 'FIRST_CONTENTFUL_PAINT_MS': {'percentile': 685, 'distributions': [{'min': 0, 'max': 1000, 'proportion': 0.9229428172942803}, {'min': 1000, 'max': 3000, 'proportion': 0.07391910739191067}, {'min': 3000, 'proportion': 0.0031380753138075326}], 'category': 'FAST'}, 'FIRST_INPUT_DELAY_MS': {'percentile': 3, 'distributions': [{'min': 0, 'max': 100, 'proportion': 0.9975527684307128}, {'min': 100, 'max': 300, 'proportion': 0.0012236157846436222}, {'min': 300, 'proportion': 0.0012236157846436222}], 'category': 'FAST'}, 'LARGEST_CONTENTFUL_PAINT_MS': {'percentile': 1059, 'distributions': [{'min': 0, 'max': 2500, 'proportion': 0.9783972125435626}, {'min': 2500, 'max': 4000, 'proportion': 0.01742160278745659}, {'min': 4000, 'proportion': 0.00418118466898957}], 'category': 'FAST'}}, 'overall_category': 'FAST', 'initial_url': 'https://www.karwei.nl/assortiment/k/bouwmaterialen'}
# COUNTER:  15
# ['id', 'metrics', 'overall_category', 'initial_url']
# https://www.stmiddelkoop.nl/bouwmaterialen/
# {'id': 'https://www.stmiddelkoop.nl/bouwmaterialen/', 'metrics': {'CUMULATIVE_LAYOUT_SHIFT_SCORE': {'percentile': 0, 'distributions': [{'min': 0, 'max': 10, 'proportion': 0.9483048002685469}, {'min': 10, 'max': 25, 'proportion': 0.02047667002349783}, {'min': 25, 'proportion': 0.031218529707955706}], 'category': 'FAST'}, 'FIRST_CONTENTFUL_PAINT_MS': {'percentile': 950, 'distributions': [{'min': 0, 'max': 1000, 'proportion': 0.7766957689724642}, {'min': 1000, 'max': 3000, 'proportion': 0.21323035594358608}, {'min': 3000, 'proportion': 0.010073875083948958}], 'category': 'FAST'}, 'FIRST_INPUT_DELAY_MS': {'percentile': 3, 'distributions': [{'min': 0, 'max': 100, 'proportion': 0.9691553761891042}, {'min': 100, 'max': 300, 'proportion': 0.010089362928797932}, {'min': 300, 'proportion': 0.020755260882098614}], 'category': 'FAST'}, 'LARGEST_CONTENTFUL_PAINT_MS': {'percentile': 1418, 'distributions': [{'min': 0, 'max': 2500, 'proportion': 0.9690992767915828}, {'min': 2500, 'max': 4000, 'proportion': 0.019723865877712}, {'min': 4000, 'proportion': 0.01117685733070346}], 'category': 'FAST'}}, 'overall_category': 'FAST', 'initial_url': 'https://www.stmiddelkoop.nl/bouwmaterialen/'}
# COUNTER:  16
# ['id', 'metrics', 'overall_category', 'initial_url']
# https://www.gamma.nl/assortiment/k/bouwmaterialen
# {'id': 'https://www.gamma.nl/assortiment/k/bouwmaterialen', 'metrics': {'CUMULATIVE_LAYOUT_SHIFT_SCORE': {'percentile': 3, 'distributions': [{'min': 0, 'max': 10, 'proportion': 0.9848359525778871}, {'min': 10, 'max': 25, 'proportion': 0.011855527984560231}, {'min': 25, 'proportion': 0.0033085194375516926}], 'category': 'FAST'}, 'FIRST_CONTENTFUL_PAINT_MS': {'percentile': 652, 'distributions': [{'min': 0, 'max': 1000, 'proportion': 0.9099344978165942}, {'min': 1000, 'max': 3000, 'proportion': 0.08351528384279477}, {'min': 3000, 'proportion': 0.006550218340611361}], 'category': 'FAST'}, 'FIRST_INPUT_DELAY_MS': {'percentile': 3, 'distributions': [{'min': 0, 'max': 100, 'proportion': 0.9925962487660421}, {'min': 100, 'max': 300, 'proportion': 0.005182625863770981}, {'min': 300, 'proportion': 0.002221125370187565}], 'category': 'FAST'}, 'LARGEST_CONTENTFUL_PAINT_MS': {'percentile': 943, 'distributions': [{'min': 0, 'max': 2500, 'proportion': 0.9754901960784317}, {'min': 2500, 'max': 4000, 'proportion': 0.016612200435729856}, {'min': 4000, 'proportion': 0.007897603485838792}], 'category': 'FAST'}}, 'overall_category': 'FAST', 'initial_url': 'https://www.gamma.nl/assortiment/k/bouwmaterialen'}
# COUNTER:  17
# ['id', 'metrics', 'overall_category', 'initial_url']
# https://www.verdouw.nu/
# {'id': 'https://www.verdouw.nu/', 'metrics': {'CUMULATIVE_LAYOUT_SHIFT_SCORE': {'percentile': 11, 'distributions': [{'min': 0, 'max': 10, 'proportion': 0.740802675585285}, {'min': 10, 'max': 25, 'proportion': 0.09791898922333714}, {'min': 25, 'proportion': 0.16127833519137985}], 'category': 'AVERAGE'}, 'FIRST_CONTENTFUL_PAINT_MS': {'percentile': 818, 'distributions': [{'min': 0, 'max': 1000, 'proportion': 0.8343140860610495}, {'min': 1000, 'max': 3000, 'proportion': 0.14582567120264764}, {'min': 3000, 'proportion': 0.019860242736300094}], 'category': 'FAST'}, 'FIRST_INPUT_DELAY_MS': {'percentile': 2, 'distributions': [{'min': 0, 'max': 100, 'proportion': 0.9876241938295278}, {'min': 100, 'max': 300, 'proportion': 0.010632734878856546}, {'min': 300, 'proportion': 0.001743071291615828}], 'category': 'FAST'}, 'LARGEST_CONTENTFUL_PAINT_MS': {'percentile': 2043, 'distributions': [{'min': 0, 'max': 2500, 'proportion': 0.8534088832023324}, {'min': 2500, 'max': 4000, 'proportion': 0.11515262292085446}, {'min': 4000, 'proportion': 0.03143849387680446}], 'category': 'FAST'}}, 'overall_category': 'AVERAGE', 'initial_url': 'https://www.verdouw.nu/'}
# COUNTER:  18
# ['error']
# https://www.bouwpartner.com/ : WEBSITE GIVES ERROR
# COUNTER:  19
# ['error']
# https://nl.wikipedia.org/wiki/Bouwmateriaal : WEBSITE GIVES ERROR
# COUNTER:  20
# ['error']
# https://www.bakkerdehouthandel.nl/blog/bouwmaterialen/ : WEBSITE GIVES ERROR
# COUNTER:  21
# ['error']
# http://www.bouwmaterialen-nederland.nl/ : WEBSITE GIVES ERROR
# COUNTER:  22
# ['error']
# https://www.makroshop.be/nl/bouwen-en-gereedschappen/bouwmaterialen : WEBSITE GIVES ERROR
# COUNTER:  23
# ['error']
# https://www.praxis.nl/bouwmaterialen/b1/ : WEBSITE GIVES ERROR
# COUNTER:  24
# ['error']
# https://www.oke-bouwmaterialen.nl/ : WEBSITE GIVES ERROR
# COUNTER:  25
# ['error']
# https://www.joostdevree.nl/shtmls/bouwmaterialen.shtml : WEBSITE GIVES ERROR
# COUNTER:  26
# ['error']
# http://www.hout-en-bouwmaterialen.nl/ : WEBSITE GIVES ERROR
# COUNTER:  27
# ['error']
# https://www.limtrade.nl/af-bouw/bouwmaterialen : WEBSITE GIVES ERROR
# COUNTER:  28
# ['error']
# https://www.bouwcenter.nl/driessen/bouwmaterialen/ : WEBSITE GIVES ERROR
# COUNTER:  29
# ['error']
# https://gebruiktebouwmaterialen.com/ : WEBSITE GIVES ERROR
# COUNTER:  30
# ['error']
# https://www.nelemans.nl/bouwcenter/bouwmaterialen/ : WEBSITE GIVES ERROR
# COUNTER:  31
# ['error']
# https://www.bouwhof.nl/bouw/bouwmaterialen/ : WEBSITE GIVES ERROR
# COUNTER:  32
# ['error']
# https://www.houthandelonline.nl/bouwmaterialen : WEBSITE GIVES ERROR
# COUNTER:  33
# ['error']
# https://www.wienerberger.nl/verkooppunten/bouwmaterialen.html : WEBSITE GIVES ERROR
# COUNTER:  34
# ['error']
# https://www.flexbouwmateriaal.nl/ : WEBSITE GIVES ERROR
# COUNTER:  35
# ['error']
# https://www.crijnsbouwmaterialen.nl/nl/bouwmaterialen-kopen : WEBSITE GIVES ERROR
# COUNTER:  36
# ['error']
# https://www.3mnederland.nl/3M/nl_NL/p/c/bouwmaterialen/ : WEBSITE GIVES ERROR
# COUNTER:  37
# ['error']
# https://www.breukers.nl/bouwmaterialen : WEBSITE GIVES ERROR
# COUNTER:  38
# ['error']
# https://www.bouwmaterialenzeeland.nl/ : WEBSITE GIVES ERROR
# COUNTER:  39
# ['error']
# https://www.ggoedkoop.nl/ : WEBSITE GIVES ERROR
# COUNTER:  40
# ['error']
# https://www.eco-bouwmaterialen.nl/ : WEBSITE GIVES ERROR
# COUNTER:  41
# ['error']
# https://www.witzand.nl/ : WEBSITE GIVES ERROR
# COUNTER:  42
# ['error']
# https://www.groenebouwmaterialen.nl/ : WEBSITE GIVES ERROR
# COUNTER:  43
# ['error']
# https://www.hormes.nl/bouwmaterialen/ : WEBSITE GIVES ERROR
# COUNTER:  44
# ['error']
# https://www.vidaxl.nl/g/115/bouwmaterialen : WEBSITE GIVES ERROR
# COUNTER:  45
# ['error']
# https://www.marktplaats.nl/u/2e-hands-bouwmaterialen/20098676/ : WEBSITE GIVES ERROR
# COUNTER:  46
# ['error']
# https://www.bouwbink.nl/bouwmaterialen : WEBSITE GIVES ERROR
# COUNTER:  47
# ['error']
# https://www.veldhovense.nl/ : WEBSITE GIVES ERROR
# COUNTER:  48
# ['error']
# https://www.boer-staphorst.nl/klussen-bouwen/bouwmaterialen : WEBSITE GIVES ERROR
# COUNTER:  49
# ['error']
# https://www.houthandelvangelder.nl/bouwmaterialen/ : WEBSITE GIVES ERROR
# COUNTER:  50
# Amount of usable returns:  15
# Run time:  17039.529719352722  minutes
#                                                   URL   FCP   LCP  FID  CLS
# 0              https://www.bouwmaat.nl/bouwmaterialen  1216  2474    5   82
# 1   https://www.hornbach.nl/shop/Bouwmateriaal/S44...   487   538    5   65
# 2       https://www.bouwbestel.nl/bouwmaterialen.html   841  1008    3   45
# 3               https://www.online-bouwmaterialen.nl/   NaN   NaN  NaN  NaN
# 4                                 https://www.bmn.nl/   NaN   NaN  NaN  NaN
# 5                         https://www.bouwonline.com/  1307  2451   22   93
# 6            https://www.bol.com/nl/m/bouwmaterialen/   528   609    3    7
# 7                           https://www.pontmeyer.nl/  2679  3950    4   51
# 8                https://www.bouwmaterialenkopen.com/   NaN   NaN  NaN  NaN
# 9                     https://www.debouwmarktshop.nl/  2473  2957    8   81
# 10             https://www.huisman.nl/bouwmaterialen/   722  2711    3   21
# 11           https://www.sleiderink.nl/bouwmaterialen   635   814    5    1
# 12                https://www.houtenbouwmaterialen.nl  1179  1759    3   11
# 13                         https://www.raabkarcher.nl  2216  4592    3   24
# 14  https://www.karwei.nl/assortiment/k/bouwmateri...   685  1059    3    4
# 15        https://www.stmiddelkoop.nl/bouwmaterialen/   950  1418    3    0
# 16  https://www.gamma.nl/assortiment/k/bouwmaterialen   652   943    3    3
# 17                            https://www.verdouw.nu/   818  2043    2   11
# 18                       https://www.bouwpartner.com/   NaN   NaN  NaN  NaN
# 19        https://nl.wikipedia.org/wiki/Bouwmateriaal   NaN   NaN  NaN  NaN
# 20  https://www.bakkerdehouthandel.nl/blog/bouwmat...   NaN   NaN  NaN  NaN
# 21            http://www.bouwmaterialen-nederland.nl/   NaN   NaN  NaN  NaN
# 22  https://www.makroshop.be/nl/bouwen-en-gereedsc...   NaN   NaN  NaN  NaN
# 23           https://www.praxis.nl/bouwmaterialen/b1/   NaN   NaN  NaN  NaN
# 24                 https://www.oke-bouwmaterialen.nl/   NaN   NaN  NaN  NaN
# 25  https://www.joostdevree.nl/shtmls/bouwmaterial...   NaN   NaN  NaN  NaN
# 26              http://www.hout-en-bouwmaterialen.nl/   NaN   NaN  NaN  NaN
# 27     https://www.limtrade.nl/af-bouw/bouwmaterialen   NaN   NaN  NaN  NaN
# 28  https://www.bouwcenter.nl/driessen/bouwmateria...   NaN   NaN  NaN  NaN
# 29               https://gebruiktebouwmaterialen.com/   NaN   NaN  NaN  NaN
# 30  https://www.nelemans.nl/bouwcenter/bouwmateria...   NaN   NaN  NaN  NaN
# 31        https://www.bouwhof.nl/bouw/bouwmaterialen/   NaN   NaN  NaN  NaN
# 32     https://www.houthandelonline.nl/bouwmaterialen   NaN   NaN  NaN  NaN
# 33  https://www.wienerberger.nl/verkooppunten/bouw...   NaN   NaN  NaN  NaN
# 34                  https://www.flexbouwmateriaal.nl/   NaN   NaN  NaN  NaN
# 35  https://www.crijnsbouwmaterialen.nl/nl/bouwmat...   NaN   NaN  NaN  NaN
# 36  https://www.3mnederland.nl/3M/nl_NL/p/c/bouwma...   NaN   NaN  NaN  NaN
# 37             https://www.breukers.nl/bouwmaterialen   NaN   NaN  NaN  NaN
# 38              https://www.bouwmaterialenzeeland.nl/   NaN   NaN  NaN  NaN
# 39                          https://www.ggoedkoop.nl/   NaN   NaN  NaN  NaN
# 40                 https://www.eco-bouwmaterialen.nl/   NaN   NaN  NaN  NaN
# 41                            https://www.witzand.nl/   NaN   NaN  NaN  NaN
# 42               https://www.groenebouwmaterialen.nl/   NaN   NaN  NaN  NaN
# 43              https://www.hormes.nl/bouwmaterialen/   NaN   NaN  NaN  NaN
# 44         https://www.vidaxl.nl/g/115/bouwmaterialen   NaN   NaN  NaN  NaN
# 45  https://www.marktplaats.nl/u/2e-hands-bouwmate...   NaN   NaN  NaN  NaN
# 46             https://www.bouwbink.nl/bouwmaterialen   NaN   NaN  NaN  NaN
# 47                        https://www.veldhovense.nl/   NaN   NaN  NaN  NaN
# 48  https://www.boer-staphorst.nl/klussen-bouwen/b...   NaN   NaN  NaN  NaN
# 49  https://www.houthandelvangelder.nl/bouwmateria...   NaN   NaN  NaN  NaN
